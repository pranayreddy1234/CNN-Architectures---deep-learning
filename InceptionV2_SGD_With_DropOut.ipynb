# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# %%
batch_size = 128 #batch size as 128
num_classes = 100 # we got 100 classes dataset
epochs = 50 # iterations over dataset

# %%
img_rows, img_cols = 32, 32

# %%
#Channels first means that in a specific tensor (consider a photo), you would have (Number_Of_Channels, Height , Width).
# we convert channel first to channel last.
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
#Model Creation
inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Dropout(0.5)(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Dropout(0.5)(conv_2)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)
conv_2 = Dropout(0.5)(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Dropout(0.5)(conv_3)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)
conv_3 = Dropout(0.5)(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
#conv_1 = Dropout(0.5)(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Dropout(0.5)(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)
conv_3 = Dropout(0.5)(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_4 = Dropout(0.5)(conv_4)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_21 = Dropout(0.5)(conv_21)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_4 = Dropout(0.5)(conv_4)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(512, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 32)   896         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_69[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 32, 32, 32)   0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 32)   9248        dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 32)   1056        conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 32, 32)   1056        conv2d_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 32, 32, 32)   0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 32, 32, 32)   0           conv2d_77[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 32, 32, 32)   0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 32, 32)   9248        dropout_25[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 32, 32)   9248        dropout_27[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 32, 32, 32)   1056        dropout_29[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 32, 32, 32)   0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 32, 32, 32)   0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 32, 32, 32)   0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 32, 32, 32)   1056        conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 128)  0           dropout_26[0][0]
#                                                                  dropout_28[0][0]
#                                                                  dropout_30[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_86[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 32, 32, 32)   0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 32, 32, 32)   0           conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 32)   7200        dropout_31[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 32, 32, 32)   7200        dropout_32[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 32, 32, 32)   0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 32, 32, 32)   0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 128)  0           conv2d_85[0][0]
#                                                                  conv2d_88[0][0]
#                                                                  dropout_33[0][0]
#                                                                  dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_91[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 32, 32, 32)   0           conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 32, 32, 32)   3104        conv2d_95[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 128)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 32, 32)   3104        dropout_35[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 32, 32, 32)   3104        dropout_35[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 32, 32, 32)   0           conv2d_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 32, 32, 32)   3104        conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 32, 32, 32)   0           conv2d_99[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 192)  0           conv2d_93[0][0]
#                                                                  conv2d_94[0][0]
#                                                                  dropout_36[0][0]
#                                                                  conv2d_97[0][0]
#                                                                  conv2d_98[0][0]
#                                                                  dropout_37[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 30, 30, 32)   55328       concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 28, 28, 64)   18496       conv2d_100[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 7, 7, 64)     0           conv2d_101[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3136)         0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          1606144     flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          51300       dense_4[0][0]
# ==================================================================================================
# Total params: 1,908,260
# Trainable params: 1,908,260
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.3
    )
datagen.fit(x_train)

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.SGD(learning_rate = 0.01, momentum = 0.9),
              metrics=['accuracy'])

# %%
# model.fit(x_train, y_train,
#           batch_size=batch_size,
#           epochs=epochs,
#           verbose=1,
#           validation_data=(x_test, y_test))
# save model after each epoch
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
checkpoint = ModelCheckpoint("inception_SGD_Dropout.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
#hist=model.fit(x_train, y_train, batch_size=128, epochs=100, verbose=1, validation_data=(x_test, y_test),callbacks=[early, checkpoint])
hist=model.fit_generator(datagen.flow(x_train, y_train, batch_size=128),
                    steps_per_epoch = len(x_train) / 128, epochs=100, validation_data=(x_test, y_test),callbacks=[early,checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 391/390 [==============================] - ETA: 0s - loss: 4.4471 - accuracy: 0.0319
# Epoch 00001: val_accuracy improved from -inf to 0.01000, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 53s 136ms/step - loss: 4.4471 - accuracy: 0.0319 - val_loss: 4.7267 - val_accuracy: 0.0100
# Epoch 2/100
# 391/390 [==============================] - ETA: 0s - loss: 4.1221 - accuracy: 0.0700
# Epoch 00002: val_accuracy improved from 0.01000 to 0.02400, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 54s 138ms/step - loss: 4.1221 - accuracy: 0.0700 - val_loss: 4.5578 - val_accuracy: 0.0240
# Epoch 3/100
# 391/390 [==============================] - ETA: 0s - loss: 3.8670 - accuracy: 0.1044
# Epoch 00003: val_accuracy improved from 0.02400 to 0.04070, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 54s 139ms/step - loss: 3.8670 - accuracy: 0.1044 - val_loss: 4.4264 - val_accuracy: 0.0407
# Epoch 4/100
# 391/390 [==============================] - ETA: 0s - loss: 3.6655 - accuracy: 0.1354
# Epoch 00004: val_accuracy improved from 0.04070 to 0.04610, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 3.6655 - accuracy: 0.1354 - val_loss: 4.5058 - val_accuracy: 0.0461
# Epoch 5/100
# 391/390 [==============================] - ETA: 0s - loss: 3.5108 - accuracy: 0.1634
# Epoch 00005: val_accuracy improved from 0.04610 to 0.05560, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 3.5108 - accuracy: 0.1634 - val_loss: 4.4181 - val_accuracy: 0.0556
# Epoch 6/100
# 391/390 [==============================] - ETA: 0s - loss: 3.3880 - accuracy: 0.1821
# Epoch 00006: val_accuracy improved from 0.05560 to 0.09530, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 141ms/step - loss: 3.3880 - accuracy: 0.1821 - val_loss: 4.0925 - val_accuracy: 0.0953
# Epoch 7/100
# 391/390 [==============================] - ETA: 0s - loss: 3.2527 - accuracy: 0.2096
# Epoch 00007: val_accuracy did not improve from 0.09530
# 391/390 [==============================] - 55s 141ms/step - loss: 3.2527 - accuracy: 0.2096 - val_loss: 4.4872 - val_accuracy: 0.0526
# Epoch 8/100
# 391/390 [==============================] - ETA: 0s - loss: 3.1516 - accuracy: 0.2269
# Epoch 00008: val_accuracy improved from 0.09530 to 0.13970, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 141ms/step - loss: 3.1516 - accuracy: 0.2269 - val_loss: 3.7370 - val_accuracy: 0.1397
# Epoch 9/100
# 391/390 [==============================] - ETA: 0s - loss: 3.0656 - accuracy: 0.2452
# Epoch 00009: val_accuracy improved from 0.13970 to 0.15270, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 3.0656 - accuracy: 0.2452 - val_loss: 3.7427 - val_accuracy: 0.1527
# Epoch 10/100
# 391/390 [==============================] - ETA: 0s - loss: 2.9830 - accuracy: 0.2577
# Epoch 00010: val_accuracy did not improve from 0.15270
# 391/390 [==============================] - 55s 140ms/step - loss: 2.9830 - accuracy: 0.2577 - val_loss: 3.6932 - val_accuracy: 0.1423
# Epoch 11/100
# 391/390 [==============================] - ETA: 0s - loss: 2.9249 - accuracy: 0.2731
# Epoch 00011: val_accuracy improved from 0.15270 to 0.18030, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.9249 - accuracy: 0.2731 - val_loss: 3.5052 - val_accuracy: 0.1803
# Epoch 12/100
# 391/390 [==============================] - ETA: 0s - loss: 2.8558 - accuracy: 0.2848
# Epoch 00012: val_accuracy improved from 0.18030 to 0.18210, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.8558 - accuracy: 0.2848 - val_loss: 3.4826 - val_accuracy: 0.1821
# Epoch 13/100
# 391/390 [==============================] - ETA: 0s - loss: 2.7858 - accuracy: 0.2979
# Epoch 00013: val_accuracy improved from 0.18210 to 0.18600, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.7858 - accuracy: 0.2979 - val_loss: 3.5350 - val_accuracy: 0.1860
# Epoch 14/100
# 391/390 [==============================] - ETA: 0s - loss: 2.7270 - accuracy: 0.3093
# Epoch 00014: val_accuracy improved from 0.18600 to 0.23830, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.7270 - accuracy: 0.3093 - val_loss: 3.2025 - val_accuracy: 0.2383
# Epoch 15/100
# 391/390 [==============================] - ETA: 0s - loss: 2.6827 - accuracy: 0.3208
# Epoch 00015: val_accuracy did not improve from 0.23830
# 391/390 [==============================] - 55s 140ms/step - loss: 2.6827 - accuracy: 0.3208 - val_loss: 3.2889 - val_accuracy: 0.2222
# Epoch 16/100
# 391/390 [==============================] - ETA: 0s - loss: 2.6319 - accuracy: 0.3291
# Epoch 00016: val_accuracy improved from 0.23830 to 0.27260, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.6319 - accuracy: 0.3291 - val_loss: 2.9571 - val_accuracy: 0.2726
# Epoch 17/100
# 391/390 [==============================] - ETA: 0s - loss: 2.5989 - accuracy: 0.3360
# Epoch 00017: val_accuracy did not improve from 0.27260
# 391/390 [==============================] - 55s 140ms/step - loss: 2.5989 - accuracy: 0.3360 - val_loss: 3.2684 - val_accuracy: 0.2280
# Epoch 18/100
# 391/390 [==============================] - ETA: 0s - loss: 2.5371 - accuracy: 0.3475
# Epoch 00018: val_accuracy did not improve from 0.27260
# 391/390 [==============================] - 55s 140ms/step - loss: 2.5371 - accuracy: 0.3475 - val_loss: 3.0860 - val_accuracy: 0.2581
# Epoch 19/100
# 391/390 [==============================] - ETA: 0s - loss: 2.5176 - accuracy: 0.3523
# Epoch 00019: val_accuracy did not improve from 0.27260
# 391/390 [==============================] - 55s 140ms/step - loss: 2.5176 - accuracy: 0.3523 - val_loss: 3.0709 - val_accuracy: 0.2628
# Epoch 20/100
# 391/390 [==============================] - ETA: 0s - loss: 2.4700 - accuracy: 0.3631
# Epoch 00020: val_accuracy improved from 0.27260 to 0.27350, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.4700 - accuracy: 0.3631 - val_loss: 3.0713 - val_accuracy: 0.2735
# Epoch 21/100
# 391/390 [==============================] - ETA: 0s - loss: 2.4264 - accuracy: 0.3736
# Epoch 00021: val_accuracy improved from 0.27350 to 0.30070, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.4264 - accuracy: 0.3736 - val_loss: 2.8441 - val_accuracy: 0.3007
# Epoch 22/100
# 391/390 [==============================] - ETA: 0s - loss: 2.3828 - accuracy: 0.3819
# Epoch 00022: val_accuracy improved from 0.30070 to 0.31190, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.3828 - accuracy: 0.3819 - val_loss: 2.7765 - val_accuracy: 0.3119
# Epoch 23/100
# 391/390 [==============================] - ETA: 0s - loss: 2.3640 - accuracy: 0.3825
# Epoch 00023: val_accuracy did not improve from 0.31190
# 391/390 [==============================] - 55s 140ms/step - loss: 2.3640 - accuracy: 0.3825 - val_loss: 3.0798 - val_accuracy: 0.2704
# Epoch 24/100
# 391/390 [==============================] - ETA: 0s - loss: 2.3262 - accuracy: 0.3976
# Epoch 00024: val_accuracy improved from 0.31190 to 0.33910, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.3262 - accuracy: 0.3976 - val_loss: 2.6683 - val_accuracy: 0.3391
# Epoch 25/100
# 391/390 [==============================] - ETA: 0s - loss: 2.2958 - accuracy: 0.4013
# Epoch 00025: val_accuracy did not improve from 0.33910
# 391/390 [==============================] - 55s 140ms/step - loss: 2.2958 - accuracy: 0.4013 - val_loss: 2.6802 - val_accuracy: 0.3345
# Epoch 26/100
# 391/390 [==============================] - ETA: 0s - loss: 2.2747 - accuracy: 0.4040
# Epoch 00026: val_accuracy did not improve from 0.33910
# 391/390 [==============================] - 54s 139ms/step - loss: 2.2747 - accuracy: 0.4040 - val_loss: 2.7955 - val_accuracy: 0.3142
# Epoch 27/100
# 391/390 [==============================] - ETA: 0s - loss: 2.2338 - accuracy: 0.4128
# Epoch 00027: val_accuracy did not improve from 0.33910
# 391/390 [==============================] - 55s 140ms/step - loss: 2.2338 - accuracy: 0.4128 - val_loss: 2.6995 - val_accuracy: 0.3349
# Epoch 28/100
# 391/390 [==============================] - ETA: 0s - loss: 2.2057 - accuracy: 0.4158
# Epoch 00028: val_accuracy did not improve from 0.33910
# 391/390 [==============================] - 55s 140ms/step - loss: 2.2057 - accuracy: 0.4158 - val_loss: 2.7499 - val_accuracy: 0.3242
# Epoch 29/100
# 391/390 [==============================] - ETA: 0s - loss: 2.1732 - accuracy: 0.4268
# Epoch 00029: val_accuracy did not improve from 0.33910
# 391/390 [==============================] - 55s 140ms/step - loss: 2.1732 - accuracy: 0.4268 - val_loss: 2.6850 - val_accuracy: 0.3359
# Epoch 30/100
# 391/390 [==============================] - ETA: 0s - loss: 2.1456 - accuracy: 0.4343
# Epoch 00030: val_accuracy improved from 0.33910 to 0.35420, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.1456 - accuracy: 0.4343 - val_loss: 2.6493 - val_accuracy: 0.3542
# Epoch 31/100
# 391/390 [==============================] - ETA: 0s - loss: 2.1213 - accuracy: 0.4397
# Epoch 00031: val_accuracy improved from 0.35420 to 0.37350, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.1213 - accuracy: 0.4397 - val_loss: 2.5272 - val_accuracy: 0.3735
# Epoch 32/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0966 - accuracy: 0.4422
# Epoch 00032: val_accuracy did not improve from 0.37350
# 391/390 [==============================] - 55s 140ms/step - loss: 2.0966 - accuracy: 0.4422 - val_loss: 2.6218 - val_accuracy: 0.3615
# Epoch 33/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0755 - accuracy: 0.4472
# Epoch 00033: val_accuracy did not improve from 0.37350
# 391/390 [==============================] - 55s 140ms/step - loss: 2.0755 - accuracy: 0.4472 - val_loss: 2.7885 - val_accuracy: 0.3329
# Epoch 34/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0560 - accuracy: 0.4528
# Epoch 00034: val_accuracy did not improve from 0.37350
# 391/390 [==============================] - 54s 139ms/step - loss: 2.0560 - accuracy: 0.4528 - val_loss: 2.6672 - val_accuracy: 0.3414
# Epoch 35/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0329 - accuracy: 0.4568
# Epoch 00035: val_accuracy improved from 0.37350 to 0.39130, saving model to inception_SGD_Dropout.hdf5
# 391/390 [==============================] - 55s 140ms/step - loss: 2.0329 - accuracy: 0.4568 - val_loss: 2.4448 - val_accuracy: 0.3913
# Epoch 36/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0071 - accuracy: 0.4599
# Epoch 00036: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 55s 140ms/step - loss: 2.0071 - accuracy: 0.4599 - val_loss: 2.5968 - val_accuracy: 0.3661
# Epoch 37/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9797 - accuracy: 0.4696
# Epoch 00037: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 55s 140ms/step - loss: 1.9797 - accuracy: 0.4696 - val_loss: 2.6226 - val_accuracy: 0.3575
# Epoch 38/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9582 - accuracy: 0.4746
# Epoch 00038: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 55s 140ms/step - loss: 1.9582 - accuracy: 0.4746 - val_loss: 2.5124 - val_accuracy: 0.3828
# Epoch 39/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9360 - accuracy: 0.4788
# Epoch 00039: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 54s 139ms/step - loss: 1.9360 - accuracy: 0.4788 - val_loss: 2.5150 - val_accuracy: 0.3831
# Epoch 40/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9174 - accuracy: 0.4832
# Epoch 00040: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 55s 140ms/step - loss: 1.9174 - accuracy: 0.4832 - val_loss: 2.4322 - val_accuracy: 0.3892
# Epoch 41/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9053 - accuracy: 0.4868
# Epoch 00041: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 55s 139ms/step - loss: 1.9053 - accuracy: 0.4868 - val_loss: 2.5626 - val_accuracy: 0.3746
# Epoch 42/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8932 - accuracy: 0.4880
# Epoch 00042: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 54s 139ms/step - loss: 1.8932 - accuracy: 0.4880 - val_loss: 2.6349 - val_accuracy: 0.3719
# Epoch 43/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8685 - accuracy: 0.4958
# Epoch 00043: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 54s 139ms/step - loss: 1.8685 - accuracy: 0.4958 - val_loss: 2.6875 - val_accuracy: 0.3651
# Epoch 44/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8420 - accuracy: 0.4992
# Epoch 00044: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 54s 139ms/step - loss: 1.8420 - accuracy: 0.4992 - val_loss: 2.5397 - val_accuracy: 0.3884
# Epoch 45/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8254 - accuracy: 0.5036Restoring model weights from the end of the best epoch.
#
# Epoch 00045: val_accuracy did not improve from 0.39130
# 391/390 [==============================] - 55s 140ms/step - loss: 1.8254 - accuracy: 0.5036 - val_loss: 2.5492 - val_accuracy: 0.3799
# Epoch 00045: early stopping

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
#confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.446564789035149
# Recall: 0.3913
# Accuracy: 0.3913

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#Model Creation
inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Dropout(0.5)(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Dropout(0.5)(conv_2)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)
conv_2 = Dropout(0.5)(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Dropout(0.5)(conv_3)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)
conv_3 = Dropout(0.5)(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
#conv_1 = Dropout(0.5)(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Dropout(0.5)(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)
conv_3 = Dropout(0.5)(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_4 = Dropout(0.5)(conv_4)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Dropout(0.5)(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_21 = Dropout(0.5)(conv_21)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_4 = Dropout(0.5)(conv_4)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(512, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

model.load_weights('../weights/InceptionV2_SGD_With_DropOut.hdf5')

y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
