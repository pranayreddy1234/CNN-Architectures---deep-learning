# %%
#importing the required packages and libraries.
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.layers import ELU
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# %%
batch_size = 128 #batch size as 128
num_classes = 100 # we got 100 classes dataset
epochs = 50 # iterations over dataset
elu_alpha = 0.1

# %%
img_rows, img_cols = 32, 32

# %%
#Channels first means that in a specific tensor (consider a photo), you would have (Number_Of_Channels, Height , Width).
# we convert channel first to channel last.
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
initializer = keras.initializers.HeNormal()
#layer = tf.keras.layers.Dense(3, kernel_initializer=initializer)

# %%
#building the sequential model

model = Sequential()
model.add(Conv2D(input_shape = input_shape,filters=64,kernel_size=(3,3),padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Dropout(0.5))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(ELU(alpha=elu_alpha))
model.add(Flatten())
model.add(Dense(units=2048))
model.add(ELU(alpha=elu_alpha))
model.add(Dense(units=2048))
model.add(ELU(alpha=elu_alpha))
model.add(Dense(units=100, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# elu_34 (ELU)                 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# elu_35 (ELU)                 (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# elu_36 (ELU)                 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# elu_37 (ELU)                 (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# elu_38 (ELU)                 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# elu_39 (ELU)                 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# elu_40 (ELU)                 (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# elu_41 (ELU)                 (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# elu_42 (ELU)                 (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# elu_43 (ELU)                 (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# elu_44 (ELU)                 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# elu_45 (ELU)                 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# elu_46 (ELU)                 (None, 2, 2, 512)         0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1, 1, 512)         0
# _________________________________________________________________
# elu_47 (ELU)                 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2048)              1050624
# _________________________________________________________________
# elu_48 (ELU)                 (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# elu_49 (ELU)                 (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               204900
# =================================================================
# Total params: 20,166,564
# Trainable params: 20,166,564
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # this is the augmentation configuration we will use for training
# train_datagen = ImageDataGenerator(
#         rescale=1./255,
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True)

# # this is the augmentation configuration we will use for testing:
# # only rescaling
# test_datagen = ImageDataGenerator(rescale=1./255)


#set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
    #zoom_range=0.3
    )
datagen.fit(x_train)

# %%
#initial_learning_rate = 0.1
#lr_schedule = keras.optimizers.schedules.ExponentialDecay(
     #initial_learning_rate,
    #  decay_steps=1000,
    #  decay_rate=0.96,
    #  staircase=True)

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(learning_rate = 0.0001, clipvalue = 0.8),
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping
import datetime
import os

checkpoint = ModelCheckpoint('VGG_Adam_DropOut.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# history = model.fit(x_train, y_train,
#           batch_size=batch_size,
#           epochs=epochs,
#           verbose=1,
#           validation_data=(x_test, y_test),callbacks=[early,checkpoint])
history=model.fit_generator(datagen.flow(x_train, y_train, batch_size=128),
                     steps_per_epoch = len(x_train) / 128, epochs=100, validation_data=(x_test, y_test),callbacks=[early,checkpoint])
# Out:
# WARNING:tensorflow:From <ipython-input-44-911cd66ead66>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 391/390 [==============================] - ETA: 0s - loss: 4.4725 - accuracy: 0.0178
# Epoch 00001: val_accuracy improved from -inf to 0.01710, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 40s 101ms/step - loss: 4.4725 - accuracy: 0.0178 - val_loss: 4.6118 - val_accuracy: 0.0171
# Epoch 2/100
# 391/390 [==============================] - ETA: 0s - loss: 4.2094 - accuracy: 0.0339
# Epoch 00002: val_accuracy improved from 0.01710 to 0.02870, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 4.2094 - accuracy: 0.0339 - val_loss: 4.3905 - val_accuracy: 0.0287
# Epoch 3/100
# 391/390 [==============================] - ETA: 0s - loss: 4.0290 - accuracy: 0.0536
# Epoch 00003: val_accuracy improved from 0.02870 to 0.04720, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 4.0290 - accuracy: 0.0536 - val_loss: 4.2809 - val_accuracy: 0.0472
# Epoch 4/100
# 391/390 [==============================] - ETA: 0s - loss: 3.8955 - accuracy: 0.0760
# Epoch 00004: val_accuracy improved from 0.04720 to 0.06700, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 3.8955 - accuracy: 0.0760 - val_loss: 4.0982 - val_accuracy: 0.0670
# Epoch 5/100
# 391/390 [==============================] - ETA: 0s - loss: 3.7798 - accuracy: 0.0968
# Epoch 00005: val_accuracy improved from 0.06700 to 0.08820, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 3.7798 - accuracy: 0.0968 - val_loss: 3.8989 - val_accuracy: 0.0882
# Epoch 6/100
# 391/390 [==============================] - ETA: 0s - loss: 3.6992 - accuracy: 0.1095
# Epoch 00006: val_accuracy improved from 0.08820 to 0.10550, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 101ms/step - loss: 3.6992 - accuracy: 0.1095 - val_loss: 3.8537 - val_accuracy: 0.1055
# Epoch 7/100
# 391/390 [==============================] - ETA: 0s - loss: 3.6039 - accuracy: 0.1266
# Epoch 00007: val_accuracy improved from 0.10550 to 0.11090, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 101ms/step - loss: 3.6039 - accuracy: 0.1266 - val_loss: 3.8325 - val_accuracy: 0.1109
# Epoch 8/100
# 391/390 [==============================] - ETA: 0s - loss: 3.4983 - accuracy: 0.1425
# Epoch 00008: val_accuracy did not improve from 0.11090
# 391/390 [==============================] - 39s 100ms/step - loss: 3.4983 - accuracy: 0.1425 - val_loss: 3.8956 - val_accuracy: 0.1103
# Epoch 9/100
# 391/390 [==============================] - ETA: 0s - loss: 3.4037 - accuracy: 0.1578
# Epoch 00009: val_accuracy improved from 0.11090 to 0.15280, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 3.4037 - accuracy: 0.1578 - val_loss: 3.5706 - val_accuracy: 0.1528
# Epoch 10/100
# 391/390 [==============================] - ETA: 0s - loss: 3.3102 - accuracy: 0.1804
# Epoch 00010: val_accuracy improved from 0.15280 to 0.16050, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 3.3102 - accuracy: 0.1804 - val_loss: 3.5415 - val_accuracy: 0.1605
# Epoch 11/100
# 391/390 [==============================] - ETA: 0s - loss: 3.2172 - accuracy: 0.1966
# Epoch 00011: val_accuracy improved from 0.16050 to 0.18480, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 3.2172 - accuracy: 0.1966 - val_loss: 3.4482 - val_accuracy: 0.1848
# Epoch 12/100
# 391/390 [==============================] - ETA: 0s - loss: 3.1434 - accuracy: 0.2122
# Epoch 00012: val_accuracy improved from 0.18480 to 0.20370, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 3.1434 - accuracy: 0.2122 - val_loss: 3.2975 - val_accuracy: 0.2037
# Epoch 13/100
# 391/390 [==============================] - ETA: 0s - loss: 3.0757 - accuracy: 0.2274
# Epoch 00013: val_accuracy improved from 0.20370 to 0.20590, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 3.0757 - accuracy: 0.2274 - val_loss: 3.3324 - val_accuracy: 0.2059
# Epoch 14/100
# 391/390 [==============================] - ETA: 0s - loss: 3.0073 - accuracy: 0.2396
# Epoch 00014: val_accuracy improved from 0.20590 to 0.20720, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 40s 101ms/step - loss: 3.0073 - accuracy: 0.2396 - val_loss: 3.3702 - val_accuracy: 0.2072
# Epoch 15/100
# 391/390 [==============================] - ETA: 0s - loss: 2.9499 - accuracy: 0.2501
# Epoch 00015: val_accuracy improved from 0.20720 to 0.23090, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 101ms/step - loss: 2.9499 - accuracy: 0.2501 - val_loss: 3.1906 - val_accuracy: 0.2309
# Epoch 16/100
# 391/390 [==============================] - ETA: 0s - loss: 2.8848 - accuracy: 0.2617
# Epoch 00016: val_accuracy improved from 0.23090 to 0.24280, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.8848 - accuracy: 0.2617 - val_loss: 3.1314 - val_accuracy: 0.2428
# Epoch 17/100
# 391/390 [==============================] - ETA: 0s - loss: 2.8365 - accuracy: 0.2747
# Epoch 00017: val_accuracy improved from 0.24280 to 0.26460, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.8365 - accuracy: 0.2747 - val_loss: 2.9779 - val_accuracy: 0.2646
# Epoch 18/100
# 391/390 [==============================] - ETA: 0s - loss: 2.7860 - accuracy: 0.2831
# Epoch 00018: val_accuracy improved from 0.26460 to 0.29180, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.7860 - accuracy: 0.2831 - val_loss: 2.8434 - val_accuracy: 0.2918
# Epoch 19/100
# 391/390 [==============================] - ETA: 0s - loss: 2.7336 - accuracy: 0.2954
# Epoch 00019: val_accuracy did not improve from 0.29180
# 391/390 [==============================] - 39s 100ms/step - loss: 2.7336 - accuracy: 0.2954 - val_loss: 2.8780 - val_accuracy: 0.2818
# Epoch 20/100
# 391/390 [==============================] - ETA: 0s - loss: 2.6948 - accuracy: 0.3025
# Epoch 00020: val_accuracy did not improve from 0.29180
# 391/390 [==============================] - 39s 99ms/step - loss: 2.6948 - accuracy: 0.3025 - val_loss: 2.8818 - val_accuracy: 0.2874
# Epoch 21/100
# 391/390 [==============================] - ETA: 0s - loss: 2.6356 - accuracy: 0.3166
# Epoch 00021: val_accuracy improved from 0.29180 to 0.30440, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 2.6356 - accuracy: 0.3166 - val_loss: 2.8017 - val_accuracy: 0.3044
# Epoch 22/100
# 391/390 [==============================] - ETA: 0s - loss: 2.5810 - accuracy: 0.3287
# Epoch 00022: val_accuracy improved from 0.30440 to 0.30980, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 101ms/step - loss: 2.5810 - accuracy: 0.3287 - val_loss: 2.7481 - val_accuracy: 0.3098
# Epoch 23/100
# 391/390 [==============================] - ETA: 0s - loss: 2.5497 - accuracy: 0.3349
# Epoch 00023: val_accuracy improved from 0.30980 to 0.33680, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.5497 - accuracy: 0.3349 - val_loss: 2.6124 - val_accuracy: 0.3368
# Epoch 24/100
# 391/390 [==============================] - ETA: 0s - loss: 2.4960 - accuracy: 0.3444
# Epoch 00024: val_accuracy did not improve from 0.33680
# 391/390 [==============================] - 39s 99ms/step - loss: 2.4960 - accuracy: 0.3444 - val_loss: 2.6765 - val_accuracy: 0.3290
# Epoch 25/100
# 391/390 [==============================] - ETA: 0s - loss: 2.4528 - accuracy: 0.3562
# Epoch 00025: val_accuracy improved from 0.33680 to 0.33770, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.4528 - accuracy: 0.3562 - val_loss: 2.6685 - val_accuracy: 0.3377
# Epoch 26/100
# 391/390 [==============================] - ETA: 0s - loss: 2.4219 - accuracy: 0.3638
# Epoch 00026: val_accuracy did not improve from 0.33770
# 391/390 [==============================] - 39s 99ms/step - loss: 2.4219 - accuracy: 0.3638 - val_loss: 2.7622 - val_accuracy: 0.3208
# Epoch 27/100
# 391/390 [==============================] - ETA: 0s - loss: 2.3757 - accuracy: 0.3694
# Epoch 00027: val_accuracy improved from 0.33770 to 0.37090, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.3757 - accuracy: 0.3694 - val_loss: 2.4930 - val_accuracy: 0.3709
# Epoch 28/100
# 391/390 [==============================] - ETA: 0s - loss: 2.3364 - accuracy: 0.3817
# Epoch 00028: val_accuracy did not improve from 0.37090
# 391/390 [==============================] - 39s 99ms/step - loss: 2.3364 - accuracy: 0.3817 - val_loss: 2.5013 - val_accuracy: 0.3667
# Epoch 29/100
# 391/390 [==============================] - ETA: 0s - loss: 2.2981 - accuracy: 0.3888
# Epoch 00029: val_accuracy improved from 0.37090 to 0.38960, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.2981 - accuracy: 0.3888 - val_loss: 2.3923 - val_accuracy: 0.3896
# Epoch 30/100
# 391/390 [==============================] - ETA: 0s - loss: 2.2689 - accuracy: 0.3985
# Epoch 00030: val_accuracy improved from 0.38960 to 0.39930, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 101ms/step - loss: 2.2689 - accuracy: 0.3985 - val_loss: 2.3712 - val_accuracy: 0.3993
# Epoch 31/100
# 391/390 [==============================] - ETA: 0s - loss: 2.2339 - accuracy: 0.4029
# Epoch 00031: val_accuracy did not improve from 0.39930
# 391/390 [==============================] - 39s 99ms/step - loss: 2.2339 - accuracy: 0.4029 - val_loss: 2.5134 - val_accuracy: 0.3844
# Epoch 32/100
# 391/390 [==============================] - ETA: 0s - loss: 2.1991 - accuracy: 0.4123
# Epoch 00032: val_accuracy improved from 0.39930 to 0.39990, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.1991 - accuracy: 0.4123 - val_loss: 2.3750 - val_accuracy: 0.3999
# Epoch 33/100
# 391/390 [==============================] - ETA: 0s - loss: 2.1633 - accuracy: 0.4214
# Epoch 00033: val_accuracy did not improve from 0.39990
# 391/390 [==============================] - 39s 99ms/step - loss: 2.1633 - accuracy: 0.4214 - val_loss: 2.4050 - val_accuracy: 0.3985
# Epoch 34/100
# 391/390 [==============================] - ETA: 0s - loss: 2.1514 - accuracy: 0.4226
# Epoch 00034: val_accuracy improved from 0.39990 to 0.42790, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 2.1514 - accuracy: 0.4226 - val_loss: 2.2289 - val_accuracy: 0.4279
# Epoch 35/100
# 391/390 [==============================] - ETA: 0s - loss: 2.1064 - accuracy: 0.4316
# Epoch 00035: val_accuracy did not improve from 0.42790
# 391/390 [==============================] - 39s 99ms/step - loss: 2.1064 - accuracy: 0.4316 - val_loss: 2.3414 - val_accuracy: 0.4118
# Epoch 36/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0791 - accuracy: 0.4384
# Epoch 00036: val_accuracy did not improve from 0.42790
# 391/390 [==============================] - 39s 99ms/step - loss: 2.0791 - accuracy: 0.4384 - val_loss: 2.3413 - val_accuracy: 0.4154
# Epoch 37/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0627 - accuracy: 0.4435
# Epoch 00037: val_accuracy did not improve from 0.42790
# 391/390 [==============================] - 39s 99ms/step - loss: 2.0627 - accuracy: 0.4435 - val_loss: 2.3179 - val_accuracy: 0.4229
# Epoch 38/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0296 - accuracy: 0.4506
# Epoch 00038: val_accuracy did not improve from 0.42790
# 391/390 [==============================] - 39s 100ms/step - loss: 2.0296 - accuracy: 0.4506 - val_loss: 2.3400 - val_accuracy: 0.4185
# Epoch 39/100
# 391/390 [==============================] - ETA: 0s - loss: 2.0037 - accuracy: 0.4560
# Epoch 00039: val_accuracy improved from 0.42790 to 0.44130, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 2.0037 - accuracy: 0.4560 - val_loss: 2.1884 - val_accuracy: 0.4413
# Epoch 40/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9769 - accuracy: 0.4632
# Epoch 00040: val_accuracy did not improve from 0.44130
# 391/390 [==============================] - 39s 99ms/step - loss: 1.9769 - accuracy: 0.4632 - val_loss: 2.3133 - val_accuracy: 0.4255
# Epoch 41/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9627 - accuracy: 0.4651
# Epoch 00041: val_accuracy did not improve from 0.44130
# 391/390 [==============================] - 39s 99ms/step - loss: 1.9627 - accuracy: 0.4651 - val_loss: 2.3876 - val_accuracy: 0.4222
# Epoch 42/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9342 - accuracy: 0.4712
# Epoch 00042: val_accuracy improved from 0.44130 to 0.44600, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 1.9342 - accuracy: 0.4712 - val_loss: 2.1861 - val_accuracy: 0.4460
# Epoch 43/100
# 391/390 [==============================] - ETA: 0s - loss: 1.9133 - accuracy: 0.4773
# Epoch 00043: val_accuracy did not improve from 0.44600
# 391/390 [==============================] - 39s 99ms/step - loss: 1.9133 - accuracy: 0.4773 - val_loss: 2.2343 - val_accuracy: 0.4445
# Epoch 44/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8898 - accuracy: 0.4817
# Epoch 00044: val_accuracy improved from 0.44600 to 0.46540, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 1.8898 - accuracy: 0.4817 - val_loss: 2.1287 - val_accuracy: 0.4654
# Epoch 45/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8713 - accuracy: 0.4875
# Epoch 00045: val_accuracy did not improve from 0.46540
# 391/390 [==============================] - 39s 99ms/step - loss: 1.8713 - accuracy: 0.4875 - val_loss: 2.1416 - val_accuracy: 0.4638
# Epoch 46/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8434 - accuracy: 0.4936
# Epoch 00046: val_accuracy did not improve from 0.46540
# 391/390 [==============================] - 39s 100ms/step - loss: 1.8434 - accuracy: 0.4936 - val_loss: 2.2632 - val_accuracy: 0.4449
# Epoch 47/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8283 - accuracy: 0.4957
# Epoch 00047: val_accuracy improved from 0.46540 to 0.47570, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 1.8283 - accuracy: 0.4957 - val_loss: 2.0614 - val_accuracy: 0.4757
# Epoch 48/100
# 391/390 [==============================] - ETA: 0s - loss: 1.8060 - accuracy: 0.5023
# Epoch 00048: val_accuracy did not improve from 0.47570
# 391/390 [==============================] - 39s 99ms/step - loss: 1.8060 - accuracy: 0.5023 - val_loss: 2.1590 - val_accuracy: 0.4671
# Epoch 49/100
# 391/390 [==============================] - ETA: 0s - loss: 1.7889 - accuracy: 0.5049
# Epoch 00049: val_accuracy did not improve from 0.47570
# 391/390 [==============================] - 38s 98ms/step - loss: 1.7889 - accuracy: 0.5049 - val_loss: 2.1425 - val_accuracy: 0.4680
# Epoch 50/100
# 391/390 [==============================] - ETA: 0s - loss: 1.7697 - accuracy: 0.5098
# Epoch 00050: val_accuracy improved from 0.47570 to 0.48690, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 1.7697 - accuracy: 0.5098 - val_loss: 2.0411 - val_accuracy: 0.4869
# Epoch 51/100
# 391/390 [==============================] - ETA: 0s - loss: 1.7494 - accuracy: 0.5126
# Epoch 00051: val_accuracy did not improve from 0.48690
# 391/390 [==============================] - 39s 99ms/step - loss: 1.7494 - accuracy: 0.5126 - val_loss: 2.1291 - val_accuracy: 0.4791
# Epoch 52/100
# 391/390 [==============================] - ETA: 0s - loss: 1.7346 - accuracy: 0.5175
# Epoch 00052: val_accuracy did not improve from 0.48690
# 391/390 [==============================] - 39s 99ms/step - loss: 1.7346 - accuracy: 0.5175 - val_loss: 2.0568 - val_accuracy: 0.4755
# Epoch 53/100
# 391/390 [==============================] - ETA: 0s - loss: 1.7156 - accuracy: 0.5205
# Epoch 00053: val_accuracy did not improve from 0.48690
# 391/390 [==============================] - 39s 99ms/step - loss: 1.7156 - accuracy: 0.5205 - val_loss: 2.1046 - val_accuracy: 0.4782
# Epoch 54/100
# 391/390 [==============================] - ETA: 0s - loss: 1.6960 - accuracy: 0.5240
# Epoch 00054: val_accuracy did not improve from 0.48690
# 391/390 [==============================] - 39s 100ms/step - loss: 1.6960 - accuracy: 0.5240 - val_loss: 2.2399 - val_accuracy: 0.4639
# Epoch 55/100
# 391/390 [==============================] - ETA: 0s - loss: 1.6799 - accuracy: 0.5308
# Epoch 00055: val_accuracy did not improve from 0.48690
# 391/390 [==============================] - 39s 99ms/step - loss: 1.6799 - accuracy: 0.5308 - val_loss: 2.0553 - val_accuracy: 0.4859
# Epoch 56/100
# 391/390 [==============================] - ETA: 0s - loss: 1.6614 - accuracy: 0.5371
# Epoch 00056: val_accuracy did not improve from 0.48690
# 391/390 [==============================] - 39s 99ms/step - loss: 1.6614 - accuracy: 0.5371 - val_loss: 2.0793 - val_accuracy: 0.4856
# Epoch 57/100
# 391/390 [==============================] - ETA: 0s - loss: 1.6445 - accuracy: 0.5399
# Epoch 00057: val_accuracy improved from 0.48690 to 0.50790, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 38s 98ms/step - loss: 1.6445 - accuracy: 0.5399 - val_loss: 1.9572 - val_accuracy: 0.5079
# Epoch 58/100
# 391/390 [==============================] - ETA: 0s - loss: 1.6314 - accuracy: 0.5437
# Epoch 00058: val_accuracy did not improve from 0.50790
# 391/390 [==============================] - 38s 98ms/step - loss: 1.6314 - accuracy: 0.5437 - val_loss: 1.9745 - val_accuracy: 0.5014
# Epoch 59/100
# 391/390 [==============================] - ETA: 0s - loss: 1.6158 - accuracy: 0.5470
# Epoch 00059: val_accuracy did not improve from 0.50790
# 391/390 [==============================] - 38s 98ms/step - loss: 1.6158 - accuracy: 0.5470 - val_loss: 1.9939 - val_accuracy: 0.4993
# Epoch 60/100
# 391/390 [==============================] - ETA: 0s - loss: 1.6027 - accuracy: 0.5506
# Epoch 00060: val_accuracy did not improve from 0.50790
# 391/390 [==============================] - 38s 98ms/step - loss: 1.6027 - accuracy: 0.5506 - val_loss: 2.0616 - val_accuracy: 0.4954
# Epoch 61/100
# 391/390 [==============================] - ETA: 0s - loss: 1.5765 - accuracy: 0.5557
# Epoch 00061: val_accuracy improved from 0.50790 to 0.51390, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 1.5765 - accuracy: 0.5557 - val_loss: 1.9658 - val_accuracy: 0.5139
# Epoch 62/100
# 391/390 [==============================] - ETA: 0s - loss: 1.5745 - accuracy: 0.5547
# Epoch 00062: val_accuracy did not improve from 0.51390
# 391/390 [==============================] - 39s 99ms/step - loss: 1.5745 - accuracy: 0.5547 - val_loss: 2.0482 - val_accuracy: 0.4966
# Epoch 63/100
# 391/390 [==============================] - ETA: 0s - loss: 1.5509 - accuracy: 0.5636
# Epoch 00063: val_accuracy did not improve from 0.51390
# 391/390 [==============================] - 38s 98ms/step - loss: 1.5509 - accuracy: 0.5636 - val_loss: 1.9996 - val_accuracy: 0.5070
# Epoch 64/100
# 391/390 [==============================] - ETA: 0s - loss: 1.5318 - accuracy: 0.5665
# Epoch 00064: val_accuracy did not improve from 0.51390
# 391/390 [==============================] - 39s 99ms/step - loss: 1.5318 - accuracy: 0.5665 - val_loss: 1.9502 - val_accuracy: 0.5088
# Epoch 65/100
# 391/390 [==============================] - ETA: 0s - loss: 1.5210 - accuracy: 0.5712
# Epoch 00065: val_accuracy did not improve from 0.51390
# 391/390 [==============================] - 38s 98ms/step - loss: 1.5210 - accuracy: 0.5712 - val_loss: 1.9899 - val_accuracy: 0.5133
# Epoch 66/100
# 391/390 [==============================] - ETA: 0s - loss: 1.5099 - accuracy: 0.5723
# Epoch 00066: val_accuracy improved from 0.51390 to 0.52700, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 100ms/step - loss: 1.5099 - accuracy: 0.5723 - val_loss: 1.9036 - val_accuracy: 0.5270
# Epoch 67/100
# 391/390 [==============================] - ETA: 0s - loss: 1.4910 - accuracy: 0.5737
# Epoch 00067: val_accuracy did not improve from 0.52700
# 391/390 [==============================] - 39s 99ms/step - loss: 1.4910 - accuracy: 0.5737 - val_loss: 1.9995 - val_accuracy: 0.5143
# Epoch 68/100
# 391/390 [==============================] - ETA: 0s - loss: 1.4782 - accuracy: 0.5766
# Epoch 00068: val_accuracy did not improve from 0.52700
# 391/390 [==============================] - 39s 99ms/step - loss: 1.4782 - accuracy: 0.5766 - val_loss: 2.0410 - val_accuracy: 0.5106
# Epoch 69/100
# 391/390 [==============================] - ETA: 0s - loss: 1.4675 - accuracy: 0.5815
# Epoch 00069: val_accuracy did not improve from 0.52700
# 391/390 [==============================] - 39s 99ms/step - loss: 1.4675 - accuracy: 0.5815 - val_loss: 2.1242 - val_accuracy: 0.4994
# Epoch 70/100
# 391/390 [==============================] - ETA: 0s - loss: 1.4437 - accuracy: 0.5863
# Epoch 00070: val_accuracy did not improve from 0.52700
# 391/390 [==============================] - 39s 100ms/step - loss: 1.4437 - accuracy: 0.5863 - val_loss: 2.0408 - val_accuracy: 0.5075
# Epoch 71/100
# 391/390 [==============================] - ETA: 0s - loss: 1.4291 - accuracy: 0.5913
# Epoch 00071: val_accuracy did not improve from 0.52700
# 391/390 [==============================] - 39s 99ms/step - loss: 1.4291 - accuracy: 0.5913 - val_loss: 2.0530 - val_accuracy: 0.5111
# Epoch 72/100
# 391/390 [==============================] - ETA: 0s - loss: 1.4259 - accuracy: 0.5921
# Epoch 00072: val_accuracy did not improve from 0.52700
# 391/390 [==============================] - 39s 99ms/step - loss: 1.4259 - accuracy: 0.5921 - val_loss: 1.9086 - val_accuracy: 0.5251
# Epoch 73/100
# 391/390 [==============================] - ETA: 0s - loss: 1.4058 - accuracy: 0.5955
# Epoch 00073: val_accuracy improved from 0.52700 to 0.53170, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 1.4058 - accuracy: 0.5955 - val_loss: 1.9184 - val_accuracy: 0.5317
# Epoch 74/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3956 - accuracy: 0.6016
# Epoch 00074: val_accuracy improved from 0.53170 to 0.54090, saving model to VGG_Adam_DropOut.hdf5
# 391/390 [==============================] - 39s 99ms/step - loss: 1.3956 - accuracy: 0.6016 - val_loss: 1.8329 - val_accuracy: 0.5409
# Epoch 75/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3837 - accuracy: 0.6028
# Epoch 00075: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.3837 - accuracy: 0.6028 - val_loss: 1.9994 - val_accuracy: 0.5201
# Epoch 76/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3690 - accuracy: 0.6070
# Epoch 00076: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.3690 - accuracy: 0.6070 - val_loss: 1.9906 - val_accuracy: 0.5224
# Epoch 77/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3556 - accuracy: 0.6086
# Epoch 00077: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.3556 - accuracy: 0.6086 - val_loss: 1.9844 - val_accuracy: 0.5288
# Epoch 78/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3483 - accuracy: 0.6117
# Epoch 00078: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 100ms/step - loss: 1.3483 - accuracy: 0.6117 - val_loss: 1.9101 - val_accuracy: 0.5329
# Epoch 79/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3373 - accuracy: 0.6125
# Epoch 00079: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.3373 - accuracy: 0.6125 - val_loss: 1.8822 - val_accuracy: 0.5346
# Epoch 80/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3217 - accuracy: 0.6186
# Epoch 00080: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.3217 - accuracy: 0.6186 - val_loss: 1.9579 - val_accuracy: 0.5232
# Epoch 81/100
# 391/390 [==============================] - ETA: 0s - loss: 1.3000 - accuracy: 0.6229
# Epoch 00081: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.3000 - accuracy: 0.6229 - val_loss: 1.9071 - val_accuracy: 0.5369
# Epoch 82/100
# 391/390 [==============================] - ETA: 0s - loss: 1.2888 - accuracy: 0.6259
# Epoch 00082: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.2888 - accuracy: 0.6259 - val_loss: 1.9332 - val_accuracy: 0.5303
# Epoch 83/100
# 391/390 [==============================] - ETA: 0s - loss: 1.2905 - accuracy: 0.6250
# Epoch 00083: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 100ms/step - loss: 1.2905 - accuracy: 0.6250 - val_loss: 2.1290 - val_accuracy: 0.5112
# Epoch 84/100
# 391/390 [==============================] - ETA: 0s - loss: 1.2665 - accuracy: 0.6310Restoring model weights from the end of the best epoch.
#
# Epoch 00084: val_accuracy did not improve from 0.54090
# 391/390 [==============================] - 39s 99ms/step - loss: 1.2665 - accuracy: 0.6310 - val_loss: 1.9741 - val_accuracy: 0.5242
# Epoch 00084: early stopping

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
#confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.563649189680288
# Recall: 0.5409
# Accuracy: 0.5409

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
plt.plot(history.history['val_accuracy'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# # cell to load best wweights

# %%
#importing the required packages and libraries.
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.layers import ELU
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate

(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

initializer = keras.initializers.HeNormal()

#building the sequential model

model = Sequential()
model.add(Conv2D(input_shape = input_shape,filters=64,kernel_size=(3,3),padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Dropout(0.5))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same"))
model.add(ELU(alpha=elu_alpha))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))
model.add(ELU(alpha=elu_alpha))
model.add(Flatten())
model.add(Dense(units=2048))
model.add(ELU(alpha=elu_alpha))
model.add(Dense(units=2048))
model.add(ELU(alpha=elu_alpha))
model.add(Dense(units=100, activation="softmax"))

model.load_weights('../weights/VGG16_Adam_With_DropOut.hdf5')

y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
