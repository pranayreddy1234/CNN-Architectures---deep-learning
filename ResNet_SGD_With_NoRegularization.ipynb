# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
#importing the required packages and libraries.
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
batch_size = 128 #batch size as 128
num_classes = 100 # we got 100 classes dataset
epochs = 50 # iterations over dataset

# %%
img_rows, img_cols = 32, 32

# %%
#Channels first means that in a specific tensor (consider a photo), you would have (Number_Of_Channels, Height , Width).
# we convert channel first to channel last.
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
inputs = Input(shape=(32, 32, 3))
num_filters = 32
t = Conv2D(kernel_size=2,strides=1,filters=num_filters,padding="same")(inputs)
t = ReLU()(t)

t = Conv2D(kernel_size = (2,2),strides=1,filters = 32, padding = "same")(t)
y = ReLU()(t)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 32, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,t])
z1 = ReLU()(y)

z1 = Conv2D(kernel_size = (3,3),strides=1,filters = 32, padding = "same")(z1)
y = ReLU()(z1)
y = Conv2D(kernel_size = (3,3),strides=1,filters = 32, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z1])
z2 = ReLU()(y)

z2 = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(z2)
y = ReLU()(z2)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z2])
z3 = ReLU()(y)

z3 = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(z3)
y = ReLU()(z3)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z3])
z4 = ReLU()(y)

z4 = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(z4)
y = ReLU()(z4)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z4])
z5 = ReLU()(y)

z5 = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(z5)
y = ReLU()(z5)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z5])
z6 = ReLU()(y)

z6 = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(z6)
y = ReLU()(z6)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z6])
z7 = ReLU()(y)

z7 = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(z5)
y = ReLU()(z7)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z7])
z8 = ReLU()(y)

t = AveragePooling2D(4)(z8)
t = Flatten()(t)

outputs = Dense(100, activation='softmax')(t)

# %%
model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   416         input_1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 32, 32, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   4128        re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   4128        re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 32, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        re_lu_2[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   8256        re_lu_4[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   16448       re_lu_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           max_pooling2d_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 32, 32, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   16448       re_lu_6[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 32, 32, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   16448       re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           max_pooling2d_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 32, 32, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  32896       re_lu_8[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 32, 32, 128)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  65664       re_lu_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 128)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 32, 32, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  65664       re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 256)  131328      conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 32, 32, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 256)  262400      re_lu_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 256)  0           max_pooling2d_7[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 32, 32, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 8, 8, 256)    0           re_lu_16[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 16384)        0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          1638500     flatten[0][0]
# ==================================================================================================
# Total params: 2,281,220
# Trainable params: 2,281,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
    #zoom_range=0.3
    )
datagen.fit(x_train)

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.SGD(learning_rate = 0.001, momentum = 0.9),
              metrics=['accuracy'])

# %%
# model.fit(x_train, y_train,
#           batch_size=batch_size,
#           epochs=epochs,
#           verbose=1,
#           validation_data=(x_test, y_test))
# save model after each epoch
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
checkpoint = ModelCheckpoint("ResNet_Basic_SGD.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
#hist=model.fit(x_train, y_train, batch_size=128, epochs=100, verbose=1, validation_data=(x_test, y_test),callbacks=[early, checkpoint])
hist=model.fit_generator(datagen.flow(x_train, y_train, batch_size=128),
                    steps_per_epoch = len(x_train) / 128, epochs=50, validation_data=(x_test, y_test),callbacks=[early,checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-10-747d6d2eda58>:13: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 2.3140 - accuracy: 0.4099 - val_loss: 2.3122 - val_accuracy: 0.4193
# Epoch 23/50
# 391/390 [==============================] - ETA: 0s - loss: 2.2625 - accuracy: 0.4217
# Epoch 00023: val_accuracy did not improve from 0.41930
# 391/390 [==============================] - 85s 216ms/step - loss: 2.2625 - accuracy: 0.4217 - val_loss: 2.3096 - val_accuracy: 0.4174
# Epoch 24/50
# 391/390 [==============================] - ETA: 0s - loss: 2.2147 - accuracy: 0.4311
# Epoch 00024: val_accuracy improved from 0.41930 to 0.42550, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 2.2147 - accuracy: 0.4311 - val_loss: 2.2929 - val_accuracy: 0.4255
# Epoch 25/50
# 391/390 [==============================] - ETA: 0s - loss: 2.1731 - accuracy: 0.4407
# Epoch 00025: val_accuracy improved from 0.42550 to 0.43850, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 216ms/step - loss: 2.1731 - accuracy: 0.4407 - val_loss: 2.2441 - val_accuracy: 0.4385
# Epoch 26/50
# 391/390 [==============================] - ETA: 0s - loss: 2.1248 - accuracy: 0.4506
# Epoch 00026: val_accuracy did not improve from 0.43850
# 391/390 [==============================] - 85s 216ms/step - loss: 2.1248 - accuracy: 0.4506 - val_loss: 2.2493 - val_accuracy: 0.4344
# Epoch 27/50
# 391/390 [==============================] - ETA: 0s - loss: 2.0840 - accuracy: 0.4576
# Epoch 00027: val_accuracy improved from 0.43850 to 0.44180, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 2.0840 - accuracy: 0.4576 - val_loss: 2.2003 - val_accuracy: 0.4418
# Epoch 28/50
# 391/390 [==============================] - ETA: 0s - loss: 2.0489 - accuracy: 0.4672
# Epoch 00028: val_accuracy improved from 0.44180 to 0.45150, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 216ms/step - loss: 2.0489 - accuracy: 0.4672 - val_loss: 2.1821 - val_accuracy: 0.4515
# Epoch 29/50
# 391/390 [==============================] - ETA: 0s - loss: 2.0100 - accuracy: 0.4776
# Epoch 00029: val_accuracy did not improve from 0.45150
# 391/390 [==============================] - 85s 217ms/step - loss: 2.0100 - accuracy: 0.4776 - val_loss: 2.2388 - val_accuracy: 0.4393
# Epoch 30/50
# 391/390 [==============================] - ETA: 0s - loss: 1.9871 - accuracy: 0.4796
# Epoch 00030: val_accuracy improved from 0.45150 to 0.46010, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 216ms/step - loss: 1.9871 - accuracy: 0.4796 - val_loss: 2.1315 - val_accuracy: 0.4601
# Epoch 31/50
# 391/390 [==============================] - ETA: 0s - loss: 1.9426 - accuracy: 0.4885
# Epoch 00031: val_accuracy did not improve from 0.46010
# 391/390 [==============================] - 85s 217ms/step - loss: 1.9426 - accuracy: 0.4885 - val_loss: 2.2201 - val_accuracy: 0.4493
# Epoch 32/50
# 391/390 [==============================] - ETA: 0s - loss: 1.9075 - accuracy: 0.4981
# Epoch 00032: val_accuracy did not improve from 0.46010
# 391/390 [==============================] - 85s 216ms/step - loss: 1.9075 - accuracy: 0.4981 - val_loss: 2.1848 - val_accuracy: 0.4524
# Epoch 33/50
# 391/390 [==============================] - ETA: 0s - loss: 1.8857 - accuracy: 0.5028
# Epoch 00033: val_accuracy improved from 0.46010 to 0.46570, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 1.8857 - accuracy: 0.5028 - val_loss: 2.1298 - val_accuracy: 0.4657
# Epoch 34/50
# 391/390 [==============================] - ETA: 0s - loss: 1.8550 - accuracy: 0.5095
# Epoch 00034: val_accuracy improved from 0.46570 to 0.46640, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 216ms/step - loss: 1.8550 - accuracy: 0.5095 - val_loss: 2.1258 - val_accuracy: 0.4664
# Epoch 35/50
# 391/390 [==============================] - ETA: 0s - loss: 1.8098 - accuracy: 0.5211
# Epoch 00035: val_accuracy improved from 0.46640 to 0.48410, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 1.8098 - accuracy: 0.5211 - val_loss: 2.0927 - val_accuracy: 0.4841
# Epoch 36/50
# 391/390 [==============================] - ETA: 0s - loss: 1.7842 - accuracy: 0.5272
# Epoch 00036: val_accuracy did not improve from 0.48410
# 391/390 [==============================] - 85s 217ms/step - loss: 1.7842 - accuracy: 0.5272 - val_loss: 2.1563 - val_accuracy: 0.4611
# Epoch 37/50
# 391/390 [==============================] - ETA: 0s - loss: 1.7544 - accuracy: 0.5333
# Epoch 00037: val_accuracy did not improve from 0.48410
# 391/390 [==============================] - 85s 216ms/step - loss: 1.7544 - accuracy: 0.5333 - val_loss: 2.0941 - val_accuracy: 0.4817
# Epoch 38/50
# 391/390 [==============================] - ETA: 0s - loss: 1.7169 - accuracy: 0.5439
# Epoch 00038: val_accuracy did not improve from 0.48410
# 391/390 [==============================] - 85s 216ms/step - loss: 1.7169 - accuracy: 0.5439 - val_loss: 2.0884 - val_accuracy: 0.4834
# Epoch 39/50
# 391/390 [==============================] - ETA: 0s - loss: 1.6940 - accuracy: 0.5451
# Epoch 00039: val_accuracy did not improve from 0.48410
# 391/390 [==============================] - 85s 217ms/step - loss: 1.6940 - accuracy: 0.5451 - val_loss: 2.1478 - val_accuracy: 0.4667
# Epoch 40/50
# 391/390 [==============================] - ETA: 0s - loss: 1.6641 - accuracy: 0.5533
# Epoch 00040: val_accuracy did not improve from 0.48410
# 391/390 [==============================] - 85s 217ms/step - loss: 1.6641 - accuracy: 0.5533 - val_loss: 2.0895 - val_accuracy: 0.4819
# Epoch 41/50
# 391/390 [==============================] - ETA: 0s - loss: 1.6311 - accuracy: 0.5638
# Epoch 00041: val_accuracy improved from 0.48410 to 0.48830, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 1.6311 - accuracy: 0.5638 - val_loss: 2.0685 - val_accuracy: 0.4883
# Epoch 42/50
# 391/390 [==============================] - ETA: 0s - loss: 1.6170 - accuracy: 0.5633
# Epoch 00042: val_accuracy did not improve from 0.48830
# 391/390 [==============================] - 85s 216ms/step - loss: 1.6170 - accuracy: 0.5633 - val_loss: 2.0933 - val_accuracy: 0.4881
# Epoch 43/50
# 391/390 [==============================] - ETA: 0s - loss: 1.5904 - accuracy: 0.5724
# Epoch 00043: val_accuracy improved from 0.48830 to 0.49770, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 216ms/step - loss: 1.5904 - accuracy: 0.5724 - val_loss: 2.0308 - val_accuracy: 0.4977
# Epoch 44/50
# 391/390 [==============================] - ETA: 0s - loss: 1.5673 - accuracy: 0.5770
# Epoch 00044: val_accuracy improved from 0.49770 to 0.50270, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 1.5673 - accuracy: 0.5770 - val_loss: 2.0274 - val_accuracy: 0.5027
# Epoch 45/50
# 391/390 [==============================] - ETA: 0s - loss: 1.5351 - accuracy: 0.5841
# Epoch 00045: val_accuracy improved from 0.50270 to 0.50910, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 1.5351 - accuracy: 0.5841 - val_loss: 1.9804 - val_accuracy: 0.5091
# Epoch 46/50
# 391/390 [==============================] - ETA: 0s - loss: 1.5131 - accuracy: 0.5910
# Epoch 00046: val_accuracy did not improve from 0.50910
# 391/390 [==============================] - 85s 216ms/step - loss: 1.5131 - accuracy: 0.5910 - val_loss: 2.0741 - val_accuracy: 0.4920
# Epoch 47/50
# 391/390 [==============================] - ETA: 0s - loss: 1.4867 - accuracy: 0.5956
# Epoch 00047: val_accuracy did not improve from 0.50910
# 391/390 [==============================] - 85s 216ms/step - loss: 1.4867 - accuracy: 0.5956 - val_loss: 2.0269 - val_accuracy: 0.5047
# Epoch 48/50
# 391/390 [==============================] - ETA: 0s - loss: 1.4621 - accuracy: 0.5999
# Epoch 00048: val_accuracy did not improve from 0.50910
# 391/390 [==============================] - 85s 216ms/step - loss: 1.4621 - accuracy: 0.5999 - val_loss: 2.0317 - val_accuracy: 0.5083
# Epoch 49/50
# 391/390 [==============================] - ETA: 0s - loss: 1.4478 - accuracy: 0.6031
# Epoch 00049: val_accuracy improved from 0.50910 to 0.51000, saving model to ResNet_Basic_SGD.hdf5
# 391/390 [==============================] - 85s 217ms/step - loss: 1.4478 - accuracy: 0.6031 - val_loss: 2.0532 - val_accuracy: 0.5100
# Epoch 50/50
# 391/390 [==============================] - ETA: 0s - loss: 1.4222 - accuracy: 0.6107
# Epoch 00050: val_accuracy did not improve from 0.51000
# 391/390 [==============================] - 85s 216ms/step - loss: 1.4222 - accuracy: 0.6107 - val_loss: 2.0916 - val_accuracy: 0.4986

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
#confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.5231731225076414
# Recall: 0.4986
# Accuracy: 0.4986

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# # cell to load best weights

# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
#importing the required packages and libraries.
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

inputs = Input(shape=(32, 32, 3))
num_filters = 32
t = Conv2D(kernel_size=2,strides=1,filters=num_filters,padding="same")(inputs)
t = ReLU()(t)

t = Conv2D(kernel_size = (2,2),strides=1,filters = 32, padding = "same")(t)
y = ReLU()(t)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 32, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,t])
z1 = ReLU()(y)

z1 = Conv2D(kernel_size = (3,3),strides=1,filters = 32, padding = "same")(z1)
y = ReLU()(z1)
y = Conv2D(kernel_size = (3,3),strides=1,filters = 32, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z1])
z2 = ReLU()(y)

z2 = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(z2)
y = ReLU()(z2)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z2])
z3 = ReLU()(y)

z3 = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(z3)
y = ReLU()(z3)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 64, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z3])
z4 = ReLU()(y)

z4 = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(z4)
y = ReLU()(z4)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z4])
z5 = ReLU()(y)

z5 = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(z5)
y = ReLU()(z5)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 128, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z5])
z6 = ReLU()(y)

z6 = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(z6)
y = ReLU()(z6)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z6])
z7 = ReLU()(y)

z7 = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(z5)
y = ReLU()(z7)
y = Conv2D(kernel_size = (2,2),strides=1,filters = 256, padding = "same")(y)
y = MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(y)
y = Add()([y,z7])
z8 = ReLU()(y)

t = AveragePooling2D(4)(z8)
t = Flatten()(t)

outputs = Dense(100, activation='softmax')(t)

model = Model(inputs, outputs)

model.load_weights('../weights/ResNet_SGD_With_NoRegularization.hdf5')

y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
