# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
#importing the required packages and libraries.
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step

# %%
batch_size = 128 #batch size as 128
num_classes = 100 # we got 100 classes dataset
epochs = 50 # iterations over dataset

# %%
img_rows, img_cols = 32, 32

# %%
#Channels first means that in a specific tensor (consider a photo), you would have (Number_Of_Channels, Height , Width).
# we convert channel first to channel last.
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
#Model Creation
inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(512, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   1056        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 32)   1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 128)  0           conv2d_8[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 32)   4128        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 32)   4128        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 32)   7200        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 32)   4128        concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           conv2d_17[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 32)   3104        conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 32)   3104        conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 32)   3104        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 32)   3104        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 32)   4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 192)  0           conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 30, 30, 32)   55328       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 64)   18496       conv2d_32[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 7, 7, 64)     0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1606144     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          51300       dense[0][0]
# ==================================================================================================
# Total params: 1,908,260
# Trainable params: 1,908,260
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.3
    )
datagen.fit(x_train)

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.SGD(learning_rate = 0.001, momentum = 0.9),
              metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
checkpoint = ModelCheckpoint("inception_plain_SGD.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
#hist=model.fit(x_train, y_train, batch_size=128, epochs=100, verbose=1, validation_data=(x_test, y_test),callbacks=[early, checkpoint])
hist=model.fit_generator(datagen.flow(x_train, y_train, batch_size=128),
                    steps_per_epoch = len(x_train) / 128, epochs=50, validation_data=(x_test, y_test),callbacks=[early,checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-10-2c1a19ea56a1>:13: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 391/390 [==============================] - ETA: 0s - loss: 4.6050 - accuracy: 0.0102
# Epoch 00001: val_accuracy improved from -inf to 0.01000, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 104s 265ms/step - loss: 4.6050 - accuracy: 0.0102 - val_loss: 4.6046 - val_accuracy: 0.0100
# Epoch 2/50
# 391/390 [==============================] - ETA: 0s - loss: 4.6043 - accuracy: 0.0111
# Epoch 00002: val_accuracy improved from 0.01000 to 0.01030, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 4.6043 - accuracy: 0.0111 - val_loss: 4.6037 - val_accuracy: 0.0103
# Epoch 3/50
# 391/390 [==============================] - ETA: 0s - loss: 4.6023 - accuracy: 0.0108
# Epoch 00003: val_accuracy improved from 0.01030 to 0.01150, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 4.6023 - accuracy: 0.0108 - val_loss: 4.5999 - val_accuracy: 0.0115
# Epoch 4/50
# 391/390 [==============================] - ETA: 0s - loss: 4.5815 - accuracy: 0.0162
# Epoch 00004: val_accuracy improved from 0.01150 to 0.02530, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 4.5815 - accuracy: 0.0162 - val_loss: 4.5157 - val_accuracy: 0.0253
# Epoch 5/50
# 391/390 [==============================] - ETA: 0s - loss: 4.3439 - accuracy: 0.0441
# Epoch 00005: val_accuracy improved from 0.02530 to 0.06780, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 4.3439 - accuracy: 0.0441 - val_loss: 4.1567 - val_accuracy: 0.0678
# Epoch 6/50
# 391/390 [==============================] - ETA: 0s - loss: 4.1418 - accuracy: 0.0678
# Epoch 00006: val_accuracy improved from 0.06780 to 0.07840, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 4.1418 - accuracy: 0.0678 - val_loss: 4.0667 - val_accuracy: 0.0784
# Epoch 7/50
# 391/390 [==============================] - ETA: 0s - loss: 4.0115 - accuracy: 0.0885
# Epoch 00007: val_accuracy improved from 0.07840 to 0.11010, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 4.0115 - accuracy: 0.0885 - val_loss: 3.8945 - val_accuracy: 0.1101
# Epoch 8/50
# 391/390 [==============================] - ETA: 0s - loss: 3.8967 - accuracy: 0.1067
# Epoch 00008: val_accuracy improved from 0.11010 to 0.13300, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 3.8967 - accuracy: 0.1067 - val_loss: 3.7743 - val_accuracy: 0.1330
# Epoch 9/50
# 391/390 [==============================] - ETA: 0s - loss: 3.7958 - accuracy: 0.1210
# Epoch 00009: val_accuracy improved from 0.13300 to 0.14800, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 3.7958 - accuracy: 0.1210 - val_loss: 3.6715 - val_accuracy: 0.1480
# Epoch 10/50
# 391/390 [==============================] - ETA: 0s - loss: 3.7365 - accuracy: 0.1296
# Epoch 00010: val_accuracy did not improve from 0.14800
# 391/390 [==============================] - 102s 261ms/step - loss: 3.7365 - accuracy: 0.1296 - val_loss: 3.6941 - val_accuracy: 0.1411
# Epoch 11/50
# 391/390 [==============================] - ETA: 0s - loss: 3.6678 - accuracy: 0.1409
# Epoch 00011: val_accuracy improved from 0.14800 to 0.16950, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 3.6678 - accuracy: 0.1409 - val_loss: 3.5232 - val_accuracy: 0.1695
# Epoch 12/50
# 391/390 [==============================] - ETA: 0s - loss: 3.6118 - accuracy: 0.1504
# Epoch 00012: val_accuracy improved from 0.16950 to 0.17090, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 3.6118 - accuracy: 0.1504 - val_loss: 3.5056 - val_accuracy: 0.1709
# Epoch 13/50
# 391/390 [==============================] - ETA: 0s - loss: 3.5530 - accuracy: 0.1597
# Epoch 00013: val_accuracy improved from 0.17090 to 0.17260, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 3.5530 - accuracy: 0.1597 - val_loss: 3.4997 - val_accuracy: 0.1726
# Epoch 14/50
# 391/390 [==============================] - ETA: 0s - loss: 3.4987 - accuracy: 0.1685
# Epoch 00014: val_accuracy improved from 0.17260 to 0.20090, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.4987 - accuracy: 0.1685 - val_loss: 3.3659 - val_accuracy: 0.2009
# Epoch 15/50
# 391/390 [==============================] - ETA: 0s - loss: 3.4561 - accuracy: 0.1761
# Epoch 00015: val_accuracy improved from 0.20090 to 0.20180, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 261ms/step - loss: 3.4561 - accuracy: 0.1761 - val_loss: 3.3477 - val_accuracy: 0.2018
# Epoch 16/50
# 391/390 [==============================] - ETA: 0s - loss: 3.3988 - accuracy: 0.1867
# Epoch 00016: val_accuracy improved from 0.20180 to 0.21810, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.3988 - accuracy: 0.1867 - val_loss: 3.2677 - val_accuracy: 0.2181
# Epoch 17/50
# 391/390 [==============================] - ETA: 0s - loss: 3.3531 - accuracy: 0.1969
# Epoch 00017: val_accuracy improved from 0.21810 to 0.22180, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.3531 - accuracy: 0.1969 - val_loss: 3.2360 - val_accuracy: 0.2218
# Epoch 18/50
# 391/390 [==============================] - ETA: 0s - loss: 3.3010 - accuracy: 0.2063
# Epoch 00018: val_accuracy improved from 0.22180 to 0.23280, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.3010 - accuracy: 0.2063 - val_loss: 3.1591 - val_accuracy: 0.2328
# Epoch 19/50
# 391/390 [==============================] - ETA: 0s - loss: 3.2480 - accuracy: 0.2156
# Epoch 00019: val_accuracy improved from 0.23280 to 0.24620, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.2480 - accuracy: 0.2156 - val_loss: 3.1003 - val_accuracy: 0.2462
# Epoch 20/50
# 391/390 [==============================] - ETA: 0s - loss: 3.2033 - accuracy: 0.2239
# Epoch 00020: val_accuracy improved from 0.24620 to 0.25890, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.2033 - accuracy: 0.2239 - val_loss: 3.0766 - val_accuracy: 0.2589
# Epoch 21/50
# 391/390 [==============================] - ETA: 0s - loss: 3.1670 - accuracy: 0.2297
# Epoch 00021: val_accuracy did not improve from 0.25890
# 391/390 [==============================] - 102s 261ms/step - loss: 3.1670 - accuracy: 0.2297 - val_loss: 3.0819 - val_accuracy: 0.2519
# Epoch 22/50
# 391/390 [==============================] - ETA: 0s - loss: 3.1201 - accuracy: 0.2399
# Epoch 00022: val_accuracy improved from 0.25890 to 0.26660, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.1201 - accuracy: 0.2399 - val_loss: 2.9762 - val_accuracy: 0.2666
# Epoch 23/50
# 391/390 [==============================] - ETA: 0s - loss: 3.0877 - accuracy: 0.2467
# Epoch 00023: val_accuracy improved from 0.26660 to 0.26990, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.0877 - accuracy: 0.2467 - val_loss: 2.9976 - val_accuracy: 0.2699
# Epoch 24/50
# 391/390 [==============================] - ETA: 0s - loss: 3.0476 - accuracy: 0.2506
# Epoch 00024: val_accuracy improved from 0.26990 to 0.28600, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 3.0476 - accuracy: 0.2506 - val_loss: 2.9016 - val_accuracy: 0.2860
# Epoch 25/50
# 391/390 [==============================] - ETA: 0s - loss: 3.0036 - accuracy: 0.2614
# Epoch 00025: val_accuracy improved from 0.28600 to 0.29120, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 263ms/step - loss: 3.0036 - accuracy: 0.2614 - val_loss: 2.8753 - val_accuracy: 0.2912
# Epoch 26/50
# 391/390 [==============================] - ETA: 0s - loss: 2.9800 - accuracy: 0.2648
# Epoch 00026: val_accuracy did not improve from 0.29120
# 391/390 [==============================] - 102s 262ms/step - loss: 2.9800 - accuracy: 0.2648 - val_loss: 2.8991 - val_accuracy: 0.2856
# Epoch 27/50
# 391/390 [==============================] - ETA: 0s - loss: 2.9498 - accuracy: 0.2733
# Epoch 00027: val_accuracy did not improve from 0.29120
# 391/390 [==============================] - 102s 262ms/step - loss: 2.9498 - accuracy: 0.2733 - val_loss: 2.8750 - val_accuracy: 0.2906
# Epoch 28/50
# 391/390 [==============================] - ETA: 0s - loss: 2.9154 - accuracy: 0.2779
# Epoch 00028: val_accuracy did not improve from 0.29120
# 391/390 [==============================] - 102s 262ms/step - loss: 2.9154 - accuracy: 0.2779 - val_loss: 2.9084 - val_accuracy: 0.2872
# Epoch 29/50
# 391/390 [==============================] - ETA: 0s - loss: 2.8902 - accuracy: 0.2832
# Epoch 00029: val_accuracy improved from 0.29120 to 0.30020, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 2.8902 - accuracy: 0.2832 - val_loss: 2.8472 - val_accuracy: 0.3002
# Epoch 30/50
# 391/390 [==============================] - ETA: 0s - loss: 2.8676 - accuracy: 0.2879
# Epoch 00030: val_accuracy improved from 0.30020 to 0.32300, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 262ms/step - loss: 2.8676 - accuracy: 0.2879 - val_loss: 2.7349 - val_accuracy: 0.3230
# Epoch 31/50
# 391/390 [==============================] - ETA: 0s - loss: 2.8328 - accuracy: 0.2935
# Epoch 00031: val_accuracy did not improve from 0.32300
# 391/390 [==============================] - 102s 262ms/step - loss: 2.8328 - accuracy: 0.2935 - val_loss: 2.7407 - val_accuracy: 0.3186
# Epoch 32/50
# 391/390 [==============================] - ETA: 0s - loss: 2.8115 - accuracy: 0.2985
# Epoch 00032: val_accuracy improved from 0.32300 to 0.32480, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 2.8115 - accuracy: 0.2985 - val_loss: 2.7262 - val_accuracy: 0.3248
# Epoch 33/50
# 391/390 [==============================] - ETA: 0s - loss: 2.7722 - accuracy: 0.3068
# Epoch 00033: val_accuracy did not improve from 0.32480
# 391/390 [==============================] - 102s 262ms/step - loss: 2.7722 - accuracy: 0.3068 - val_loss: 2.7679 - val_accuracy: 0.3109
# Epoch 34/50
# 391/390 [==============================] - ETA: 0s - loss: 2.7561 - accuracy: 0.3081
# Epoch 00034: val_accuracy improved from 0.32480 to 0.32960, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 2.7561 - accuracy: 0.3081 - val_loss: 2.6855 - val_accuracy: 0.3296
# Epoch 35/50
# 391/390 [==============================] - ETA: 0s - loss: 2.7316 - accuracy: 0.3154
# Epoch 00035: val_accuracy improved from 0.32960 to 0.33060, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 102s 262ms/step - loss: 2.7316 - accuracy: 0.3154 - val_loss: 2.6901 - val_accuracy: 0.3306
# Epoch 36/50
# 391/390 [==============================] - ETA: 0s - loss: 2.7028 - accuracy: 0.3198
# Epoch 00036: val_accuracy did not improve from 0.33060
# 391/390 [==============================] - 103s 262ms/step - loss: 2.7028 - accuracy: 0.3198 - val_loss: 2.6746 - val_accuracy: 0.3271
# Epoch 37/50
# 391/390 [==============================] - ETA: 0s - loss: 2.6758 - accuracy: 0.3262
# Epoch 00037: val_accuracy improved from 0.33060 to 0.34480, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 262ms/step - loss: 2.6758 - accuracy: 0.3262 - val_loss: 2.6236 - val_accuracy: 0.3448
# Epoch 38/50
# 391/390 [==============================] - ETA: 0s - loss: 2.6603 - accuracy: 0.3285
# Epoch 00038: val_accuracy did not improve from 0.34480
# 391/390 [==============================] - 102s 262ms/step - loss: 2.6603 - accuracy: 0.3285 - val_loss: 2.6824 - val_accuracy: 0.3297
# Epoch 39/50
# 391/390 [==============================] - ETA: 0s - loss: 2.6426 - accuracy: 0.3308
# Epoch 00039: val_accuracy improved from 0.34480 to 0.34950, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 262ms/step - loss: 2.6426 - accuracy: 0.3308 - val_loss: 2.6125 - val_accuracy: 0.3495
# Epoch 40/50
# 391/390 [==============================] - ETA: 0s - loss: 2.6192 - accuracy: 0.3357
# Epoch 00040: val_accuracy improved from 0.34950 to 0.36290, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 262ms/step - loss: 2.6192 - accuracy: 0.3357 - val_loss: 2.5415 - val_accuracy: 0.3629
# Epoch 41/50
# 391/390 [==============================] - ETA: 0s - loss: 2.5917 - accuracy: 0.3403
# Epoch 00041: val_accuracy did not improve from 0.36290
# 391/390 [==============================] - 103s 262ms/step - loss: 2.5917 - accuracy: 0.3403 - val_loss: 2.5529 - val_accuracy: 0.3594
# Epoch 42/50
# 391/390 [==============================] - ETA: 0s - loss: 2.5701 - accuracy: 0.3457
# Epoch 00042: val_accuracy did not improve from 0.36290
# 391/390 [==============================] - 103s 263ms/step - loss: 2.5701 - accuracy: 0.3457 - val_loss: 2.5655 - val_accuracy: 0.3578
# Epoch 43/50
# 391/390 [==============================] - ETA: 0s - loss: 2.5558 - accuracy: 0.3492
# Epoch 00043: val_accuracy improved from 0.36290 to 0.36300, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 263ms/step - loss: 2.5558 - accuracy: 0.3492 - val_loss: 2.5321 - val_accuracy: 0.3630
# Epoch 44/50
# 391/390 [==============================] - ETA: 0s - loss: 2.5290 - accuracy: 0.3543
# Epoch 00044: val_accuracy improved from 0.36300 to 0.37240, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 262ms/step - loss: 2.5290 - accuracy: 0.3543 - val_loss: 2.4905 - val_accuracy: 0.3724
# Epoch 45/50
# 391/390 [==============================] - ETA: 0s - loss: 2.5160 - accuracy: 0.3572
# Epoch 00045: val_accuracy did not improve from 0.37240
# 391/390 [==============================] - 102s 262ms/step - loss: 2.5160 - accuracy: 0.3572 - val_loss: 2.4955 - val_accuracy: 0.3707
# Epoch 46/50
# 391/390 [==============================] - ETA: 0s - loss: 2.5023 - accuracy: 0.3625
# Epoch 00046: val_accuracy did not improve from 0.37240
# 391/390 [==============================] - 102s 262ms/step - loss: 2.5023 - accuracy: 0.3625 - val_loss: 2.5294 - val_accuracy: 0.3655
# Epoch 47/50
# 391/390 [==============================] - ETA: 0s - loss: 2.4713 - accuracy: 0.3662
# Epoch 00047: val_accuracy improved from 0.37240 to 0.37640, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 262ms/step - loss: 2.4713 - accuracy: 0.3662 - val_loss: 2.4753 - val_accuracy: 0.3764
# Epoch 48/50
# 391/390 [==============================] - ETA: 0s - loss: 2.4660 - accuracy: 0.3683
# Epoch 00048: val_accuracy improved from 0.37640 to 0.38220, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 263ms/step - loss: 2.4660 - accuracy: 0.3683 - val_loss: 2.4494 - val_accuracy: 0.3822
# Epoch 49/50
# 391/390 [==============================] - ETA: 0s - loss: 2.4441 - accuracy: 0.3687
# Epoch 00049: val_accuracy improved from 0.38220 to 0.38550, saving model to inception_plain_SGD.hdf5
# 391/390 [==============================] - 103s 263ms/step - loss: 2.4441 - accuracy: 0.3687 - val_loss: 2.4461 - val_accuracy: 0.3855
# Epoch 50/50
# 391/390 [==============================] - ETA: 0s - loss: 2.4188 - accuracy: 0.3783
# Epoch 00050: val_accuracy did not improve from 0.38550
# 391/390 [==============================] - 103s 263ms/step - loss: 2.4188 - accuracy: 0.3783 - val_loss: 2.4561 - val_accuracy: 0.3845

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
#confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.4059654250597314
# Recall: 0.3845
# Accuracy: 0.3845

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# # cell to load best weights

# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
#importing the required packages and libraries.
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D
from keras.datasets import cifar100
from keras.layers import LeakyReLU
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train /= 255 #normalising the data.
x_test /= 255 #normalising the data.
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#Model Creation
inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(512, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

model.load_weights('../weights/InceptionV2_SGD_NoRegularization.hdf5')

y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
